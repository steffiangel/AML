# %% [markdown]
# <a href="https://colab.research.google.com/github/steffiangel/AML/blob/main/Ex6(poly).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
x=6*np.random.rand(100,1)-3
y=0.5*x**2+1.5*x+2+np.random.randn(100,1)
plt.scatter(x,y,color='r')
plt.xlabel("X points")
plt.ylabel("Y points")
# Out:
# Text(0, 0.5, 'Y points')

# %%
x=np.arange(0,20)
y=[3,4,5,7,10,10,22,23,27,35,44,48,50,63,67,60,62,70,75,88]
datax=pd.DataFrame(x)
plt.figure(figsize=(10,6))
plt.scatter(x,y)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
regmodel=LinearRegression()

# %%
regmodel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score1=r2_score(y_test,regmodel.predict(x_test))
print(score1)
# Out:
# 0.6290857895480558

# %%
plt.plot(x_train,regmodel.predict(x_train),color='r')
plt.scatter(x_train,y_train)
plt.xlabel('x values')
plt.ylabel('y valuess')
# Out:
# Text(0, 0.5, 'y valuess')

# %%
from sklearn.preprocessing import PolynomialFeatures
p=PolynomialFeatures(degree=2,include_bias=True)
x_train_p=p.fit_transform(x_train)
x_test_p=p.transform(x_test)

# %%
x_train_p
# Out:
# array([[ 1.00000000e+00, -1.57511815e+00,  2.48099719e+00],
#        [ 1.00000000e+00,  2.36321857e+00,  5.58480201e+00],
#        [ 1.00000000e+00,  5.45360769e-01,  2.97418368e-01],
#        [ 1.00000000e+00,  2.82840139e+00,  7.99985442e+00],
#        [ 1.00000000e+00, -1.34893798e-01,  1.81963367e-02],
#        [ 1.00000000e+00, -2.41196270e+00,  5.81756405e+00],
#        [ 1.00000000e+00, -1.27394761e+00,  1.62294252e+00],
#        [ 1.00000000e+00,  1.99608897e+00,  3.98437119e+00],
#        [ 1.00000000e+00, -1.91542409e+00,  3.66884944e+00],
#        [ 1.00000000e+00, -1.20682394e+00,  1.45642402e+00],
#        [ 1.00000000e+00,  2.94276835e+00,  8.65988558e+00],
#        [ 1.00000000e+00,  2.09305902e+00,  4.38089604e+00],
#        [ 1.00000000e+00,  2.13199445e+00,  4.54540035e+00],
#        [ 1.00000000e+00, -1.23155826e+00,  1.51673574e+00],
#        [ 1.00000000e+00,  1.35709737e+00,  1.84171327e+00],
#        [ 1.00000000e+00, -1.06371241e+00,  1.13148409e+00],
#        [ 1.00000000e+00,  2.46070752e-01,  6.05508150e-02],
#        [ 1.00000000e+00, -2.47316301e-01,  6.11653529e-02],
#        [ 1.00000000e+00, -9.92799763e-01,  9.85651369e-01],
#        [ 1.00000000e+00,  2.28825230e+00,  5.23609857e+00],
#        [ 1.00000000e+00, -6.17655387e-01,  3.81498177e-01],
#        [ 1.00000000e+00,  1.87662055e+00,  3.52170471e+00],
#        [ 1.00000000e+00, -3.92717627e-01,  1.54227135e-01],
#        [ 1.00000000e+00, -1.44317760e+00,  2.08276160e+00],
#        [ 1.00000000e+00, -1.86854518e+00,  3.49146107e+00],
#        [ 1.00000000e+00,  1.36583340e+00,  1.86550088e+00],
#        [ 1.00000000e+00,  1.07356403e+00,  1.15253973e+00],
#        [ 1.00000000e+00, -1.13966496e+00,  1.29883623e+00],
#        [ 1.00000000e+00, -8.95884072e-01,  8.02608271e-01],
#        [ 1.00000000e+00, -4.32575380e-01,  1.87121459e-01],
#        [ 1.00000000e+00, -1.17957514e+00,  1.39139751e+00],
#        [ 1.00000000e+00,  2.17459998e+00,  4.72888508e+00],
#        [ 1.00000000e+00,  5.37543160e-02,  2.88952649e-03],
#        [ 1.00000000e+00,  2.73141781e+00,  7.46064323e+00],
#        [ 1.00000000e+00,  1.57146551e+00,  2.46950385e+00],
#        [ 1.00000000e+00,  1.89783538e+00,  3.60177912e+00],
#        [ 1.00000000e+00,  2.37549140e+00,  5.64295940e+00]])

# %%
x_test_p

# %%
remodel2=LinearRegression()

# %%
remodel2.fit(x_train_p,y_train)
y_predict2=remodel2.predict(x_test_p)
score2=r2_score(y_test,y_predict2)
print(score2)
# Out:
# 0.874098520283485

# %%
print(remodel2.coef_)
# Out:
# [[0.         1.38470373 0.51033566]]

# %%
plt.scatter(x_train,remodel2.predict(x_train_p),color='pink')
plt.scatter(x_train,y_train)
plt.xlabel('x values')
plt.ylabel('y valuess')
# Out:
# Text(0, 0.5, 'y valuess')

# %%
from sklearn.preprocessing import PolynomialFeatures
v=PolynomialFeatures(degree=3,include_bias=True)
x_train_v=v.fit_transform(x_train)
x_test_v=v.transform(x_test)

# %%
remodel3=LinearRegression()

# %%
remodel3.fit(x_train_v,y_train)
y_predict3=remodel3.predict(x_test_v)
score3=r2_score(y_test,y_predict3)
print(score3)
# Out:
# 0.8749780764124113

# %%
print(remodel3.coef_)
# Out:
# [[0.         1.3051636  0.50002679 0.01782719]]

# %%
plt.scatter(x_train,remodel3.predict(x_train_v),color='pink')
plt.scatter(x_train,y_train)
plt.xlabel('x values')
plt.ylabel('y valuess')
# Out:
# Text(0, 0.5, 'y valuess')

# %%
x=2*np.random.rand(100,1)
y=3.5*x+1+np.random.randn(100,1)
plt.scatter(x,y,color='grey')
plt.xlabel("X points")
plt.ylabel("Y points")
# Out:
# Text(0, 0.5, 'Y points')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import PolynomialFeatures
q=PolynomialFeatures(degree=8,include_bias=True)
x_train_q=q.fit_transform(x_train)
x_test_q=q.transform(x_test)

# %%
remodel4=LinearRegression()

# %%
remodel4.fit(x_train_q,y_train)
y_predict4=remodel4.predict(x_test_q)
score4=r2_score(y_test,y_predict4)
print(score4)
# Out:
# 0.6158156865231114

# %%
print(remodel4.coef_)
# Out:
# [[    0.            69.0263209   -507.56230247  1672.64589118
#   -2868.41531206  2783.6535901  -1545.72465156   458.62466781
#     -56.42241853]]

# %%
plt.scatter(x_train,remodel3.predict(x_train_v),color='red')
plt.scatter(x_train,y_train)
plt.xlabel('x values')
plt.ylabel('y valuess')
# Out:
# Text(0, 0.5, 'y valuess')
